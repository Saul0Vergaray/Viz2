# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('weather.csv')

# %%
df.head(30)
# Out:
#     MONTH  DAY  TIME  TEMP  PRESSURE
# 0       1    1     1   6.8     10207
# 1       1    1     2   5.8     10214
# 2       1    1     3   5.7     10220
# 3       1    1     4   6.0     10225
# 4       1    1     5   4.5     10230
# 5       1    1     6   2.0     10237
# 6       1    1     7   1.1     10242
# 7       1    1     8   0.7     10245
# 8       1    1     9   0.2     10248
# 9       1    1    10   2.0     10249
# 10      1    1    11   7.2     10245
# 11      1    1    12   7.9     10239
# 12      1    1    13   7.7     10231
# 13      1    1    14   7.2     10225
# 14      1    1    15   5.3     10220
# 15      1    1    16   5.0     10217
# 16      1    1    17   4.9     10205
# 17      1    1    18   4.9     10194
# 18      1    1    19   5.4     10188
# 19      1    1    20   5.7     10183
# 20      1    1    21   5.4     10170
# 21      1    1    22   5.3     10161
# 22      1    1    23   5.4     10146
# 23      1    1    24   5.6     10140
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       MONTH  DAY  TIME  TEMP  PRESSURE
# 0         1    1     1   6.8     10207
# 1         1    1     2   5.8     10214
# 2         1    1     3   5.7     10220
# 3         1    1     4   6.0     10225
# 4         1    1     5   4.5     10230
# ...     ...  ...   ...   ...       ...
# 8779     12   31    20   3.5     10265
# 8780     12   31    21   3.4     10258
# 8781     12   31    22   3.0     10253
# 8782     12   31    23   2.8     10246
# 8783     12   31    24   2.8     10239
#
# [8784 rows x 5 columns]>

# %%
sns.relplot(data=df, x='MONTH', y='TEMP' )

# %%
sns.lineplot(data=df, x='MONTH', y='TEMP' )
# Out:
# <AxesSubplot:xlabel='MONTH', ylabel='TEMP'>

# %%
sns.catplot(data=df, x='MONTH', y='TEMP' )

# %%
df.head(20).style.set_table_styles(
[{'selector':'th',
 'props': [('background', '#20A4F3'),
          ('color', 'white'), 
          ('font-family', 'verdana')]},
 
{'selector': 'td', 
'props': [('font-family', 'verdana')]},
 
{'selector': 'tr:nth-of-type(odd)',
'props': [('background', '#DCDCDC')]},

{'selector': 'tr:nth-of-type(even)',
'props': [('background', 'white')]},

]
).hide_index()
# Out:
# <style type="text/css">
# #T_53d4c_ th {
#   background: #20A4F3;
#   color: white;
#   font-family: verdana;
# }
# #T_53d4c_ td {
#   font-family: verdana;
# }
# #T_53d4c_ tr:nth-of-type(odd) {
#   background: #DCDCDC;
# }
# #T_53d4c_ tr:nth-of-type(even) {
#   background: white;
# }
# </style>
# <table id="T_53d4c_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >MONTH</th>
#       <th class="col_heading level0 col1" >DAY</th>
#       <th class="col_heading level0 col2" >TIME</th>
#       <th class="col_heading level0 col3" >TEMP</th>
#       <th class="col_heading level0 col4" >PRESSURE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_53d4c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_53d4c_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_53d4c_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_53d4c_row0_col3" class="data row0 col3" >6.800000</td>
# ...

# %%
df.head(20).style.set_table_styles(
[{'selector':'th',
 'props': [('background', '#20A4F3'),
          ('color', 'white'), 
          ('font-family', 'verdana')]},
 
{'selector': 'td', 
'props': [('font-family', 'verdana')]},
 
{'selector': 'tr:nth-of-type(odd)',
'props': [('background', '#DCDCDC')]},

{'selector': 'tr:nth-of-type(even)',
'props': [('background', 'white')]},
 
 {'selector': 'tr:hover', 
 'props': [('background-color', 'yellow')]},

]
).hide_index()
# Out:
# <style type="text/css">
# #T_b8f20_ th {
#   background: #20A4F3;
#   color: white;
#   font-family: verdana;
# }
# #T_b8f20_ td {
#   font-family: verdana;
# }
# #T_b8f20_ tr:nth-of-type(odd) {
#   background: #DCDCDC;
# }
# #T_b8f20_ tr:nth-of-type(even) {
#   background: white;
# }
# #T_b8f20_ tr:hover {
#   background-color: yellow;
# }
# </style>
# <table id="T_b8f20_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >MONTH</th>
#       <th class="col_heading level0 col1" >DAY</th>
#       <th class="col_heading level0 col2" >TIME</th>
#       <th class="col_heading level0 col3" >TEMP</th>
#       <th class="col_heading level0 col4" >PRESSURE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b8f20_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b8f20_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_b8f20_row0_col2" class="data row0 col2" >1</td>
# ...
